# %% [markdown]
# # HR - domain:     Salary Prediction

# %% [markdown]
# ## using Machine learning, supervised - regression

# %% [markdown]
# ### Reading the dataset

# %%
# importing the required library 
import pandas as pd    # used to handle the table dats's

# %%
dataset = pd.read_csv("Salary_Data.csv")  # the dataset

# %%
dataset
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %% [markdown]
# ### assign values for independent and dependent variable

# %%
# assign values for independent and dependent variable
independent = dataset[["YearsExperience"]]
# independent

# %%
dependent = dataset[["Salary"]]
# dependent

# %% [markdown]
# ### spliting the training and test set

# %%
# importing required library 
from sklearn.model_selection import train_test_split    # only importing train_test_split from sklearn library ---- memory efficient approach
# train_test_split(independent, dependent, test_size=0.30, random_state=0)   -> it returns 4 output  (x_train, x_test, y_train, y_test)

""" 
x -  input 
y - output
"""
x_train, x_test, y_train, y_test = train_test_split(independent, dependent, test_size=0.30, random_state=0)

# %%
x_train
# Out:
#     YearsExperience
# 22              7.9
# 5               2.9
# 16              5.1
# 8               3.2
# 14              4.5
# 23              8.2
# 20              6.8
# 1               1.3
# 29             10.5
# 6               3.0
# 4               2.2
# 18              5.9
# 19              6.0
# 9               3.7
# 7               3.2
# 25              9.0
# 3               2.0
# 0               1.1
# 21              7.1
# 15              4.9
# 12              4.0

# %%
x_test
# Out:
#     YearsExperience
# 2               1.5
# 28             10.3
# 13              4.1
# 10              3.9
# 26              9.5
# 24              8.7
# 27              9.6
# 11              4.0
# 17              5.3

# %%
y_train
# Out:
#       Salary
# 22  101302.0
# 5    56642.0
# 16   66029.0
# 8    64445.0
# 14   61111.0
# 23  113812.0
# 20   91738.0
# 1    46205.0
# 29  121872.0
# 6    60150.0
# 4    39891.0
# 18   81363.0
# 19   93940.0
# 9    57189.0
# 7    54445.0
# 25  105582.0
# 3    43525.0
# 0    39343.0
# 21   98273.0
# 15   67938.0
# 12   56957.0

# %%
y_test
# Out:
#       Salary
# 2    37731.0
# 28  122391.0
# 13   57081.0
# 10   63218.0
# 26  116969.0
# 24  109431.0
# 27  112635.0
# 11   55794.0
# 17   83088.0

# %% [markdown]
# ### To train the model ---- MODEL learning/creation phase

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()   # creating regressor object for the LinearRegression class
regressor.fit(x_train, y_train)   # model learning/creation   --  (1. finding weight, bais.    2. applying model base formula)
# Out:
# LinearRegression()

# %%
# HOW TO SEE THE CALCULATED -- WEIGHT AND BAIS
